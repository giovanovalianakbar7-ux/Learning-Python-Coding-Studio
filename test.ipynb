# %%
print("Hello World !")

a = float(input("Masukkan angka : "))
b = float(input("Masukkan angka 2 : "))

angka = a + b
angka2 = a - b
angka3 = a / b
angka4 = a * b
angka5 = a % b

print(angka)
print(angka2)
print(angka3)
print(angka4)
print(angka5)
# Out:
# Hello World !
# 5000000.02
# 4999999.98
# 250000000.0
# 100000.0
# 0.019999999895916592
